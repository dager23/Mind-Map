# %%
import minddmapper as mm

# %%
text="A blockchain is a distributed database or ledger that is shared among the nodes of a computer network. As a database, a blockchain stores information electronically in digital format. Blockchains are best known for their crucial role in cryptocurrency systems, such as Bitcoin, for maintaining a secure and decentralized record of transactions. The innovation with a blockchain is that it guarantees the fidelity and security of a record of data and generates trust without the need for a trusted third party.One key difference between a typical database and a blockchain is how the data is structured. A blockchain collects information together in groups, known as blocks, that hold sets of information. Blocks have certain storage capacities and, when filled, are closed and linked to the previously filled block, forming a chain of data known as the blockchain. All new information that follows that freshly added block is compiled into a newly formed block that will then also be added to the chain once filled.A database usually structures its data into tables, whereas a blockchain, as its name implies, structures its data into chunks (blocks) that are strung together. This data structure inherently makes an irreversible timeline of data when implemented in a decentralized nature. When a block is filled, it is set in stone and becomes a part of this timeline. Each block in the chain is given an exact timestamp when it is added to the chain."

# %%
mm.create_keywords_from_text(text, max_nodes=8)
# Out:
# [[[],
#   ['blockchain stores information electronically', 'blockchain'],
#   [],
#   [],
#   ['blockchain collects information together',
#    'trusted third party',
#    'one key difference',
#    'generates trust without',
#    'certain storage capacities',
#    'previously filled block',
#    'typical database',
#    'hold sets',
#    'blockchain',
#    'filled',
#    'data',
#    'chain'],
#   [],
#   ['data structure inherently makes',
#    'newly formed block',
#    'database usually structures',
#    'freshly added block',
#    'strung together',
#    'new information',
#    'name implies',
#    'decentralized nature',
#    'blockchain',
#    'filled',
#    'block',
#    'added',
#    'data',
#    'chain'],
#   [],
#   ['exact timestamp', 'block', 'added', 'chain'],
#   []],
#  {0: 'blockchain',
#   1: 'database',
#   2: 'chain',
#   3: 'block',
#   4: 'data',
#   5: 'structure',
#   6: 'timeline',
#   7: 'known',
#   8: 'given',
#   9: 'added'}]

# %%
summary = mm.generate_summary(text, top_n=10)

# %%
summary
# Out:
# 'Blocks have certain storage capacities and , when filled , are closed and linked to the previously filled block , forming a chain of data known as the blockchain . A blockchain collects information together in groups , known as blocks , that hold sets of information . As a database , a blockchain stores information electronically in digital format . When a block is filled , it is set in stone and becomes a part of this timeline . Blockchains are best known for their crucial role in cryptocurrency systems , such as Bitcoin , for maintaining a secure and decentralized record of transactions . A blockchain is a distributed database or ledger that is shared among the nodes of a computer network . Each block in the chain is given an exact timestamp when it is added to the chain . This data structure inherently makes an irreversible timeline of data when implemented in a decentralized nature .'

# %%
keywords, topics = mm.create_keywords_from_text(summary, max_nodes=10, sentence_group=1)

# %%
mm.get_mindmap(keywords, topics)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Acer\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
clean=mm.clean_text(text)

# %%
clean
# Out:
# 'A blockchain is a distributed database or ledger that is shared among the nodes of a computer network. As a database, a blockchain stores information electronically in digital format. Blockchains are best known for their crucial role in cryptocurrency systems, such as Bitcoin, for maintaining a secure and decentralized record of transactions. The innovation with a blockchain is that it guarantees the fidelity and security of a record of data and generates trust without the need for a trusted third party.One key difference between a typical database and a blockchain is how the data is structured. A blockchain collects information together in groups, known as blocks, that hold sets of information. Blocks have certain storage capacities and, when filled, are closed and linked to the previously filled block, forming a chain of data known as the blockchain. All new information that follows that freshly added block is compiled into a newly formed block that will then also be added to the 
# ...

# %%
t,k=mm.create_keywords_from_text(clean)

# %%
mm.get_mindmap(t,k)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Acer\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
t
# Out:
# [[],
#  ['blockchain stores information electronically', 'blockchain'],
#  [],
#  [],
#  ['blockchain collects information together',
#   'trusted third party',
#   'one key difference',
#   'generates trust without',
#   'certain storage capacities',
#   'blockchain',
#   'filled',
#   'chain'],
#  [],
#  ['data structure inherently makes',
#   'newly formed block',
#   'database usually structures',
#   'freshly added block',
#   'strung together',
#   'filled',
#   'block',
#   'added',
#   'chain'],
#  [],
#  ['exact timestamp', 'block', 'added', 'chain'],
#  []]

# %%
k
# Out:
# {0: 'blockchain',
#  1: 'database',
#  2: 'chain',
#  3: 'block',
#  4: 'data',
#  5: 'structure',
#  6: 'timeline',
#  7: 'known',
#  8: 'given',
#  9: 'added'}

# %%
text='Artificial intelligence is a constellation of many different technologies working together to enable machines to sense, comprehend, act, and learn with human-like levels of intelligence. Maybe that’s why it seems as though everyone’s definition of artificial intelligence is different: AI isn’t just one thing.Technologies like machine learning and natural language processing are all part of the AI landscape. Each one is evolving along its own path and, when applied in combination with data, analytics and automation, can help businesses achieve their goals, be it improving customer service or optimizing the supply chain.'

# %%
clean=mm.clean_text(text)

# %%
clean
# Out:
# 'Artificial intelligence is a constellation of many different technologies working together to enable machines to sense, comprehend, act, and learn with human-like levels of intelligence. Maybe that’s why it seems as though everyone’s definition of artificial intelligence is different: AI isn’t just one thing.Technologies like machine learning and natural language processing are all part of the AI landscape. Each one is evolving along its own path and, when applied in combination with data, analytics and automation, can help businesses achieve their goals, be it improving customer service or optimizing the supply chain.'

# %%
summary = mm.generate_summary(text, top_n=10)

# %%
summary
# Out:
# 'Artificial intelligence is a constellation of many different technologies working together to enable machines to sense , comprehend , act , and learn with human-like levels of intelligence .'

# %%
t,k=mm.create_keywords_from_text(clean)
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\gensim\models\ldamodel.py:846: RuntimeWarning: divide by zero encountered in double_scalars
#   perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
# C:\Users\Acer\anaconda3\lib\site-packages\gensim\models\ldamodel.py:846: RuntimeWarning: invalid value encountered in double_scalars
#   perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)

# %%
mm.get_mindmap(t,k)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Acer\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
scraped_data = mm.scrape_data('https://en.wikipedia.org/wiki/Wikipedia:About')

# %%
final_text = mm.clean_text(scraped_data)
print("Length of article: ", len(final_text))
keywords2, topics2 = mm.create_keywords_from_text(final_text, max_nodes=3, sentence_group=7)
mm.get_mindmap(keywords2, topics2)
# Out:
# Length of article:  2653
# <module 'matplotlib.pyplot' from 'C:\\Users\\Acer\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
